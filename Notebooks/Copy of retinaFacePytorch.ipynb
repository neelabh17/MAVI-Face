# %%
# !ifconfig

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
arr = os.listdir()
print(arr)
print("annotations_yNF4P2q__22452__e4f69fde-9736-11e9-b3c6-545200000894.jpg" in arr)
print(len(arr))
# Out:
# ['tester.jpg', '2019-06-18 16_38_17__004145__8e5653e6-91aa-11e9-9330-b827eb9ff522.jpg', '2019-06-13 16_25_53__004324__df55d23a-8dc7-11e9-874c-b827eb9ff522.jpg', '2019-06-17 16_36_55__000479__9fb0fa5a-90e8-11e9-a47b-c36597ba521f.jpg', '2019-06-17 15_01_25__013952__f9a1326a-90ce-11e9-8197-dd1eda89fb93.jpg', '2019-06-13 18_10_54__000588__25896e98-8dd6-11e9-88a4-b827eb9ff522.jpg', '2019-06-17 16_36_55__001727__721a3b6e-90e9-11e9-9099-c36597ba521f.jpg', 'annotations_yNF4P2q__237__e4f6a03e-9736-11e9-b3c6-545200000894.jpg', '2019-06-17 15_01_25__020687__57af0a8c-90d2-11e9-8b8d-dd1eda89fb93.jpg', '2019-06-17 16_36_55__000488__a0c4d4d4-90e8-11e9-a47b-c36597ba521f.jpg', '2019-06-17 16_36_55__001243__37904948-90e9-11e9-9099-c36597ba521f.jpg', 'annotations_yNF4P2q__737__e4f6a064-9736-11e9-b3c6-545200000894.jpg', '2019-06-13 16_25_53__003199__349ea772-8dc7-11e9-9d6f-b827eb9ff522.jpg', '2019-06-17 16_36_55__000039__69648dae-90e8-11e9-a47b-c36597ba521f.jpg', '2019-06-18 13_58_39__001440__557bea44-9
# ...

# %%
# !python evaluation.py
# Out:
# Reading Predictions : 100% 1/1 [00:00<00:00,  3.74it/s]
# 926
# Traceback (most recent call last):
#   File "evaluation.py", line 291, in <module>
#     evaluation(args.pred, args.gt)
#   File "evaluation.py", line 230, in evaluation
#     facebox_list, event_list, file_list, hard_gt_list, medium_gt_list, easy_gt_list = get_gt_boxes_from_txt(gt_path,'./')
# ValueError: too many values to unpack (expected 6)

# %%
# !CUDA_VISIBLE_DEVICES=0,1,2,3 python train.py --network resnet50
# Out:
# Printing net...
# RetinaFace(
#   (body): IntermediateLayerGetter(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %%
# !python test_widerface.py
# Out:
# Loading pretrained model from ./weights/Resnet50_Final.pth
# remove prefix 'module.'
# Missing keys:0
# Unused checkpoint keys:0
# Used keys:456
# Finished loading model!
# RetinaFace(
#   (body): IntermediateLayerGetter(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %%
cd /content/drive/My Drive/Retina/Project Folder/Pytorch_Retinaface_BOB
# Out:
# /content/drive/My Drive/Retina/Project Folder/Pytorch_Retinaface_BOB

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread('gang.jpg')
print(img)
plt.rcParams["figure.figsize"] = (15,15)
plt.imshow(img)
# Out:
# [[[252 251 246]
#   [252 251 246]
#   [252 251 246]
#   ...
#   [ 31  32  18]
#   [ 31  32  18]
#   [ 32  33  19]]
#
#  [[253 252 247]
#   [253 252 247]
#   [253 252 247]
#   ...
#   [ 30  31  17]
#   [ 30  31  17]
#   [ 30  31  17]]
#
#  [[253 252 247]
#   [253 252 247]
#   [253 252 247]
#   ...
#   [ 28  29  15]
#   [ 29  30  16]
#   [ 29  30  16]]
#
#  ...
#
#  [[ 62  49  33]
#   [ 64  51  35]
#   [ 64  51  35]
#   ...
#   [157 125 114]
#   [138 105  96]
#   [130  97  88]]
#
#  [[ 62  49  33]
#   [ 68  55  39]
#   [ 70  57  41]
#   ...
#   [137 105  94]
#   [106  73  64]
#   [ 95  62  53]]
#
#  [[ 63  49  36]
#   [ 70  56  43]
#   [ 74  61  45]
#   ...
#   [125  93  82]
#   [ 93  60  51]
#   [ 87  54  47]]]

# %%
# !python detect.py
# Out:
# Loading pretrained model from ./weights/Resnet50_Final.pth
# remove prefix 'module.'
# Missing keys:0
# Unused checkpoint keys:0
# Used keys:456
# Finished loading model!
# RetinaFace(
#   (body): IntermediateLayerGetter(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %%
cd /content/drive/My Drive/Retina/Project Folder/Pytorch_Retinaface_BOB/data/widerface/val
# Out:
# /content/drive/My Drive/Retina/Project Folder/Pytorch_Retinaface_BOB/data/widerface/val

# %%
# a=open("wider_val.txt","w")
i=0
for line in open("label.txt", 'r'):
    line = line.strip()
    
    if line.startswith('#'):
        i+=1
        name = line[1:].strip()
        print(("/"+name)=="/NJIS/annotations_yNF4P2q__22452__e4f69fde-9736-11e9-b3c6-545200000894.jpg")
        # a.write(name+"\n")

# a.close()
print(i)
# Out:
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# ...

# %%
cd /content/drive/My Drive/Retina/Project Folder/Pytorch_Retinaface_BOB/data/widerface/val
# Out:
# /content/drive/My Drive/Retina/Project Folder/Pytorch_Retinaface_BOB/data/widerface/val

# %%
# !CUDA_VISIBLE_DEVICES=0 python train.py --batch 32 --save_path ./out
# Out:
# Namespace(batch=32, data_path='/content/drive/My Drive/Retina/Project Folder/insightface/RetinaFace/data/retinaface', depth=50, epochs=200, eval_step=3, img_size=640, save_path='./out', save_step=10, shuffle=True, verbose=10)
# Start to train.
#
#
# Traceback (most recent call last):
#   File "train.py", line 150, in <module>
#     main()
#   File "train.py", line 99, in main
#     for iter_num,data in enumerate(dataloader_train):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 345, in __next__
#     data = self._next_data()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 856, in _next_data
#     return self._process_data(data)
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 881, in _process_data
#     data.reraise()
#   File "/usr/local/lib/python3.6/dist-packages/torch/_utils.py", line 394, in reraise
#     raise self.exc_type(msg)
# ...

# %%
cd ..
# Out:
# /content/drive/My Drive/Retina/Project Folder

# %%
# !git clone https://github.com/supernotman/RetinaFace_Pytorch.git
# Out:
# Cloning into 'RetinaFace_Pytorch'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 155 (delta 0), reused 0 (delta 0), pack-reused 152
# Receiving objects: 100% (155/155), 87.95 MiB | 21.91 MiB/s, done.
# Resolving deltas: 100% (72/72), done.

# %%
cd /content/drive/My Drive/Retina/Project Folder/RetinaFace_Pytorch_supernoman
# Out:
# /content/drive/My Drive/Retina/Project Folder/RetinaFace_Pytorch_supernoman

# %%
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/9b/c4/4a21174f32f8a7e1104798c445dacdc1d4df86f2f26722767034e4de4bff/terminaltables-3.1.0.tar.gz
# ...
#   Created wheel for terminaltables: filename=terminaltables-3.1.0-cp36-none-any.whl size=15356 sha256=3ec6bfe5ca32fafb33ef92ef39bcca664d89f21f0cf01edcb6a0d020d9613b44
#   Stored in directory: /root/.cache/pip/wheels/30/6b/50/6c75775b681fb36cdfac7f19799888ef9d8813aff9e379663e
# Successfully built terminaltables
# ...

# %%
# !sudo pip install -r requirements.txt
pip install tensorBoardX
pip install terminaltables
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/d4/ab/674e168bf7d0bc597218b3bec858d02c23fbac9ec1fec9cad878c6cee95f/scikit_image-0.15.0-cp36-cp36m-manylinux1_x86_64.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/87/2d/e4656149cbadd3a8a0369fcd1a9c7d61cc7b87b3903b85389c70c989a696/numpy-1.16.4-cp36-cp36m-manylinux1_x86_64.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/9b/c4/4a21174f32f8a7e1104798c445dacdc1d4df86f2f26722767034e4de4bff/terminaltables-3.1.0.tar.gz
# ...
#   Using cached https://files.pythonhosted.org/packages/69/60/f685fb2cfb3088736bafbc9bdbb455327bdc8906b606da9c9a81bae1c81e/torch-1.1.0-cp36-cp36m-manylinux1_x86_64.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/45/af/685bf3ce889ea191f3b916557f5677cc95a5e87b2fa120d74b5dd6d049d0/tqdm-4.32.1-py2.py3-none-any.whl
# ...

# %%
# Out:
# ...
#      |████████████████████████████████| 204kB 3.3MB/s
# ...

# %%
import numpy as np
a=np.load("jatin.npy")

# %%
a.shape
# Out:
# (1, 16800, 10)

# %%
print(a[0][1])
# Out:
# [-0.65722656 -0.5332031   1.7519531  -0.56933594  0.01805115  1.5820312
#  -0.63427734  3.7128906   1.3867188   3.5078125 ]
